# %% [markdown]
# # 🧠 Introduction to Machine Learning & Its Types
#
# Welcome to the first notebook in the Machine Learning journey!
# This notebook introduces the core concepts of ML and demonstrates basic supervised learning examples using scikit-learn.

# %% [markdown]
# ## 📘 What is Machine Learning?
#
# Machine learning (ML) is a subfield of artificial intelligence (AI) that gives computers the ability to learn from data and make predictions or decisions without being explicitly programmed.
#
# ### Types of Machine Learning
#
# 1. **Supervised Learning** – Trained with labeled data
# 2. **Unsupervised Learning** – Trained with unlabeled data
# 3. **Semi-supervised Learning** – Mix of both labeled and unlabeled data
# 4. **Reinforcement Learning** – Learns by trial and error via reward signals
#
# ### Real-World Applications
#
# | Domain | Application |
# |--------|-------------|
# | Finance | Credit scoring, fraud detection |
# | Healthcare | Disease diagnosis, drug discovery |
# | Marketing | Customer segmentation, personalization |
# | Autonomous Systems | Self-driving cars, robotics |

# %%
from sklearn.datasets import load_iris, fetch_california_housing
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Load datasets
iris = load_iris(as_frame=True)
iris_df = iris.frame

# Preview the Iris dataset
iris_df.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
#
#    target
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0

# %%
sns.pairplot(iris_df, hue='target', palette='husl')
plt.suptitle("Iris Dataset - Pairwise Features", y=1.02)
plt.show()

# %%
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import classification_report, accuracy_score

X = iris_df.drop(columns='target')
y = iris_df['target']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

knn = KNeighborsClassifier(n_neighbors=3)
knn.fit(X_train, y_train)
y_pred = knn.predict(X_test)

print("Accuracy:", accuracy_score(y_test, y_pred))
print(classification_report(y_test, y_pred, target_names=iris.target_names))
# Out:
# Accuracy: 1.0
#               precision    recall  f1-score   support
#
#       setosa       1.00      1.00      1.00        19
#   versicolor       1.00      1.00      1.00        13
#    virginica       1.00      1.00      1.00        13
#
#     accuracy                           1.00        45
#    macro avg       1.00      1.00      1.00        45
# weighted avg       1.00      1.00      1.00        45

# %%
from sklearn.linear_model import LinearRegression

housing = fetch_california_housing(as_frame=True)
housing_df = housing.frame

X = housing_df[['MedInc']]
y = housing_df['MedHouseVal']

model = LinearRegression()
model.fit(X, y)

plt.scatter(X, y, alpha=0.3)
plt.plot(X, model.predict(X), color='red')
plt.title('California Housing: Income vs House Value')
plt.xlabel('Median Income')
plt.ylabel('Median House Value')
plt.show()
